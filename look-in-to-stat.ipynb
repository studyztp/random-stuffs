# %%
from pathlib import Path
from pprint import pprint
import matplotlib.pyplot as plt

# %%
count = 0
total = 0
temp = []

output_dir = Path("/home/studyztp/test_ground/experiments/cpu-speed-diff/output")

finished_configs = {}

# check which arm experiment finished

for thread in ["1", "4"]:
    data_dir = Path(output_dir/f"{thread}-thread")
    for config in data_dir.iterdir():
        total += 1
        terminal_output_file = Path(config/"board.terminal")
        finished = False
        with open(terminal_output_file.as_posix()) as file:
            line = file.readline()
            while line:
                if "Verification    =" in line:
                    line = line.split()
                    count += 1
                    if line[2]!="SUCCESSFUL":
                        print(config.name)
                        print(line[2])
                    finished = True
                    break
                line = file.readline()
        if finished:
            # finished_configs.append(config.name)
            stats_file_path = Path(config/"stats.txt")
            with open(stats_file_path.as_posix()) as file:
                line = file.readline()
                while line:
                    if "hostSeconds" in line:
                        line = line.split()
                        time = float(line[1])
                    if "simInsts" in line:
                        line = line.split()
                        sim_insts = int(line[1])
                    line = file.readline()
            finished_configs[config.name] = {}
            finished_configs[config.name]["time"] = time
            name = (config.name).split('-')
            cpu_type = name[0]
            thread_num = name[1]
            bench = name[2]
            finished_configs[config.name]["bench"] = bench
            finished_configs[config.name]["cpu_type"] = cpu_type
            finished_configs[config.name]["thread_num"] = thread_num
            finished_configs[config.name]["sim_insts"] = sim_insts

        # else:
            # print("haven't done")
            # print(config.name)

print(f"{count} finished\n")
print(f"{total} total")
# Out:
# 39 finished
#
# 56 total

# %%
pprint(finished_configs)
# Out:
# {'O3-1-cg': {'bench': 'cg',
#              'cpu_type': 'O3',
#              'sim_insts': 6179257605,
#              'thread_num': '1',
#              'time': 54700.03},
#  'O3-1-ep': {'bench': 'ep',
#              'cpu_type': 'O3',
#              'sim_insts': 22096111311,
#              'thread_num': '1',
#              'time': 149551.23},
#  'O3-1-ft': {'bench': 'ft',
#              'cpu_type': 'O3',
#              'sim_insts': 16241051775,
#              'thread_num': '1',
#              'time': 149195.59},
#  'O3-1-is': {'bench': 'is',
#              'cpu_type': 'O3',
#              'sim_insts': 2643242762,
#              'thread_num': '1',
#              'time': 31384.47},
#  'O3-1-mg': {'bench': 'mg',
#              'cpu_type': 'O3',
#              'sim_insts': 6106647509,
#              'thread_num': '1',
#              'time': 58483.84},
#  'O3-4-cg': {'bench': 'cg',
#              'cpu_type': 'O3',
#              'sim_insts': 6232066445,
#              'thread_num': '4',
#              'time': 110900.74},
#  'O3-4-ft': {'bench': 'ft',
#              'cpu_type': 'O3',
#              'sim_insts': 16095877033,
#              'thread_num': '4',
#              'time': 157561.73},
#  'O3-4-is': {'bench': 'is',
#              'cpu_type': 'O3',
#              'sim_insts': 2550438832,
#              'thread_num': '4',
#              'time': 68311.83},
#  'O3-4-mg': {'bench': 'mg',
#              'cpu_type': 'O3',
#              'sim_insts': 6085878098,
#              'thread_num': '4',
#              'time': 84031.7},
#  'atomic-1-cg': {'bench': 'cg',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 5969677357,
#                  'thread_num': '1',
#                  'time': 7996.83},
#  'atomic-1-ep': {'bench': 'ep',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 21718078733,
#                  'thread_num': '1',
#                  'time': 28968.82},
#  'atomic-1-ft': {'bench': 'ft',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 15937933752,
#                  'thread_num': '1',
#                  'time': 25610.92},
#  'atomic-1-is': {'bench': 'is',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 2434193768,
#                  'thread_num': '1',
#                  'time': 2857.32},
#  'atomic-1-mg': {'bench': 'mg',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 5868053731,
#                  'thread_num': '1',
#                  'time': 10535.63},
#  'atomic-4-cg': {'bench': 'cg',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 6050302852,
#                  'thread_num': '4',
#                  'time': 8257.82},
#  'atomic-4-ep': {'bench': 'ep',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 21751059279,
#                  'thread_num': '4',
#                  'time': 30159.1},
#  'atomic-4-ft': {'bench': 'ft',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 15971096086,
#                  'thread_num': '4',
#                  'time': 26252.08},
#  'atomic-4-is': {'bench': 'is',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 2467389998,
#                  'thread_num': '4',
#                  'time': 2971.01},
#  'atomic-4-mg': {'bench': 'mg',
#                  'cpu_type': 'atomic',
#                  'sim_insts': 5902394714,
#                  'thread_num': '4',
#                  'time': 10799.2},
#  'minor-1-cg': {'bench': 'cg',
#                 'cpu_type': 'minor',
#                 'sim_insts': 6233164872,
#                 'thread_num': '1',
#                 'time': 34586.27},
#  'minor-1-ep': {'bench': 'ep',
#                 'cpu_type': 'minor',
#                 'sim_insts': 22189237360,
#                 'thread_num': '1',
#                 'time': 106793.95},
#  'minor-1-ft': {'bench': 'ft',
#                 'cpu_type': 'minor',
#                 'sim_insts': 16334550449,
#                 'thread_num': '1',
#                 'time': 92990.56},
#  'minor-1-is': {'bench': 'is',
#                 'cpu_type': 'minor',
#                 'sim_insts': 2643744032,
#                 'thread_num': '1',
#                 'time': 13517.23},
#  'minor-1-mg': {'bench': 'mg',
#                 'cpu_type': 'minor',
#                 'sim_insts': 6174721735,
#                 'thread_num': '1',
#                 'time': 41241.32},
#  'minor-4-cg': {'bench': 'cg',
#                 'cpu_type': 'minor',
#                 'sim_insts': 6194733347,
#                 'thread_num': '4',
#                 'time': 35246.37},
#  'minor-4-ep': {'bench': 'ep',
#                 'cpu_type': 'minor',
#                 'sim_insts': 22180064556,
#                 'thread_num': '4',
#                 'time': 112387.68},
#  'minor-4-ft': {'bench': 'ft',
#                 'cpu_type': 'minor',
#                 'sim_insts': 16341144762,
#                 'thread_num': '4',
#                 'time': 97653.91},
#  'minor-4-is': {'bench': 'is',
#                 'cpu_type': 'minor',
#                 'sim_insts': 2534568632,
#                 'thread_num': '4',
#                 'time': 14520.97},
#  'minor-4-mg': {'bench': 'mg',
#                 'cpu_type': 'minor',
#                 'sim_insts': 6158689625,
#                 'thread_num': '4',
#                 'time': 44544.95},
#  'timing-1-cg': {'bench': 'cg',
#                  'cpu_type': 'timing',
#                  'sim_insts': 6938643899,
#                  'thread_num': '1',
#                  'time': 27543.62},
#  'timing-1-ep': {'bench': 'ep',
#                  'cpu_type': 'timing',
#                  'sim_insts': 23578840142,
#                  'thread_num': '1',
#                  'time': 80289.68},
#  'timing-1-ft': {'bench': 'ft',
#                  'cpu_type': 'timing',
#                  'sim_insts': 17619863562,
#                  'thread_num': '1',
#                  'time': 72371.26},
#  'timing-1-is': {'bench': 'is',
#                  'cpu_type': 'timing',
#                  'sim_insts': 2772597540,
#                  'thread_num': '1',
#                  'time': 10462.45},
#  'timing-1-mg': {'bench': 'mg',
#                  'cpu_type': 'timing',
#                  'sim_insts': 6843923180,
#                  'thread_num': '1',
#                  'time': 31443.81},
#  'timing-4-cg': {'bench': 'cg',
#                  'cpu_type': 'timing',
#                  'sim_insts': 6578213845,
#                  'thread_num': '4',
#                  'time': 27618.19},
#  'timing-4-ep': {'bench': 'ep',
#                  'cpu_type': 'timing',
#                  'sim_insts': 23212499683,
#                  'thread_num': '4',
#                  'time': 81744.04},
#  'timing-4-ft': {'bench': 'ft',
#                  'cpu_type': 'timing',
#                  'sim_insts': 17457610303,
#                  'thread_num': '4',
#                  'time': 72019.21},
#  'timing-4-is': {'bench': 'is',
#                  'cpu_type': 'timing',
#                  'sim_insts': 2724780212,
#                  'thread_num': '4',
#                  'time': 10756.98},
#  'timing-4-mg': {'bench': 'mg',
#                  'cpu_type': 'timing',
#                  'sim_insts': 6719033374,
#                  'thread_num': '4',
#                  'time': 31107.38}}

# %%
graphs = {}

for config, data in finished_configs.items():
    bench = data["bench"]
    thread = data["thread_num"]
    cpu_type = data["cpu_type"]
    time = data["time"]
    sim_insts = data["sim_insts"]
    if thread not in graphs.keys():
        graphs[thread] = {}
    if bench not in graphs[thread].keys():
        graphs[thread][bench] = {}
    if "cpu_type" not in graphs[thread][bench].keys():
        graphs[thread][bench]["cpu_type"] = []
    if "time" not in graphs[thread][bench].keys():
        graphs[thread][bench]["time"] = []
    if "sim_insts" not in graphs[thread][bench].keys():
        graphs[thread][bench]["sim_insts"] = []
    graphs[thread][bench]["cpu_type"].append(cpu_type)
    graphs[thread][bench]["time"].append(time)
    graphs[thread][bench]["sim_insts"].append(sim_insts)

for data in graphs.values():
    for bench_data in data.values():
        cpu_type_list = bench_data["cpu_type"]
        time_list =  bench_data["time"]
        sim_insts_list = bench_data["sim_insts"]
        sorted_time_list = [x for _,x in sorted(zip(cpu_type_list,time_list))]
        sorted_sim_insts_list = [x for _,x in sorted(zip(cpu_type_list,sim_insts_list))]
        sorted_cpu_type_list = sorted(cpu_type_list)
        bench_data["cpu_type"] = sorted_cpu_type_list
        bench_data["time"] = sorted_time_list
        bench_data["sim_insts"] = sorted_sim_insts_list

# %%
pprint(graphs)
# Out:
# {'1': {'cg': {'cpu_type': ['O3', 'atomic', 'minor', 'timing'],
#               'sim_insts': [6179257605, 5969677357, 6233164872, 6938643899],
#               'time': [54700.03, 7996.83, 34586.27, 27543.62]},
#        'ep': {'cpu_type': ['O3', 'atomic', 'minor', 'timing'],
#               'sim_insts': [22096111311, 21718078733, 22189237360, 23578840142],
#               'time': [149551.23, 28968.82, 106793.95, 80289.68]},
#        'ft': {'cpu_type': ['O3', 'atomic', 'minor', 'timing'],
#               'sim_insts': [16241051775, 15937933752, 16334550449, 17619863562],
#               'time': [149195.59, 25610.92, 92990.56, 72371.26]},
#        'is': {'cpu_type': ['O3', 'atomic', 'minor', 'timing'],
#               'sim_insts': [2643242762, 2434193768, 2643744032, 2772597540],
#               'time': [31384.47, 2857.32, 13517.23, 10462.45]},
#        'mg': {'cpu_type': ['O3', 'atomic', 'minor', 'timing'],
#               'sim_insts': [6106647509, 5868053731, 6174721735, 6843923180],
#               'time': [58483.84, 10535.63, 41241.32, 31443.81]}},
#  '4': {'cg': {'cpu_type': ['O3', 'atomic', 'minor', 'timing'],
#               'sim_insts': [6232066445, 6050302852, 6194733347, 6578213845],
#               'time': [110900.74, 8257.82, 35246.37, 27618.19]},
#        'ep': {'cpu_type': ['atomic', 'minor', 'timing'],
#               'sim_insts': [21751059279, 22180064556, 23212499683],
#               'time': [30159.1, 112387.68, 81744.04]},
#        'ft': {'cpu_type': ['O3', 'atomic', 'minor', 'timing'],
#               'sim_insts': [16095877033, 15971096086, 16341144762, 17457610303],
#               'time': [157561.73, 26252.08, 97653.91, 72019.21]},
#        'is': {'cpu_type': ['O3', 'atomic', 'minor', 'timing'],
#               'sim_insts': [2550438832, 2467389998, 2534568632, 2724780212],
#               'time': [68311.83, 2971.01, 14520.97, 10756.98]},
#        'mg': {'cpu_type': ['O3', 'atomic', 'minor', 'timing'],
#               'sim_insts': [6085878098, 5902394714, 6158689625, 6719033374],
#               'time': [84031.7, 10799.2, 44544.95, 31107.38]}}}

# %%
for thread_num, thread_data in graphs.items():
    for bench, bench_data in thread_data.items():
        fig, ax = plt.subplots()
        ax.bar(bench_data["cpu_type"],bench_data["time"])

        ax.set_ylabel("time(s)")
        ax.set_xlabel("cpu type")

        ax.set_title(f"host time of {bench} with {thread_num} threads")

        plt.show()

# %%
for thread_num, thread_data in graphs.items():
    for bench, bench_data in thread_data.items():
        fig, ax = plt.subplots()
        time_list = bench_data["time"]
        sim_insts_list = bench_data["sim_insts"]
        inst_per_sec_list = [float(insts/time) for insts, time in zip(sim_insts_list,time_list)]

        ax.bar(bench_data["cpu_type"],inst_per_sec_list)

        ax.set_title(f"inst/sec sim speed of {bench} with {thread_num} threads")

        ax.set_ylabel("insts/sec")
        ax.set_xlabel("cpu type")

        plt.show()

# %%
for thread_num, thread_data in graphs.items():
    for bench, bench_data in thread_data.items():
        fig, ax = plt.subplots()
        time_list = bench_data["time"]
        cpu_type_list = bench_data["cpu_type"]
        atomic_time = time_list[cpu_type_list.index("atomic")]
        speedup_list = [time/atomic_time for time in time_list]

        ax.bar(cpu_type_list,speedup_list)

        ax.set_title(f"speedup according to atomic of {bench} with {thread_num} threads")

        # ax.set_ylabel("")
        ax.set_xlabel("cpu type")

        plt.show()
